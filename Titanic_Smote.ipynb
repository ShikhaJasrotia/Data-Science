# %%
import seaborn as sns

# %%
data=sns.load_dataset("titanic")

# %%
x=data.columns
x
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
y=data.corr().columns
dataset=data[y]

# %%
char=[]
for i in x:
    if i not in y:
        char.append(i)
char
# Out:
# ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive']

# %%
char
# Out:
# ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive']

# %%
dataset["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
d1=dataset["survived"]==0
d2=dataset["survived"]==1

# %%
k1=dataset[d1]
k1.shape
# Out:
# (549, 8)

# %%
k2=dataset[d2]
k2.shape
# Out:
# (342, 8)

# %%
k1.shape[0]-k2.shape[0]
# Out:
# 207

# %%
k2[0:3].values.mean(axis=0)
# Out:
# array([1.0, 1.6666666666666667, 33.0, 0.6666666666666666, 0.0,
#        44.10276666666667, 0.0, 0.3333333333333333], dtype=object)

# %%
k2[0:3].values
# Out:
# array([[1, 1, 38.0, 1, 0, 71.2833, False, False],
#        [1, 3, 26.0, 0, 0, 7.925, False, True],
#        [1, 1, 35.0, 1, 0, 53.1, False, False]], dtype=object)

# %%
import numpy as np
r=[]
for i in range(0,207):
    p=np.random.randint(0,342)
    #q=np.random.randint(30,81)
    r.append(k2[p:p+3].values.mean(axis=0))

# %%
import pandas as pd

# %%
r=pd.DataFrame(r)

# %%
# changing r table column names to dataset columns
r.columns=dataset.columns

# %%
k2.append(r)
# Out:
#      survived    pclass        age     sibsp     parch        fare  \
# 1         1.0  1.000000  38.000000  1.000000  0.000000   71.283300
# 2         1.0  3.000000  26.000000  0.000000  0.000000    7.925000
# 3         1.0  1.000000  35.000000  1.000000  0.000000   53.100000
# 8         1.0  3.000000  27.000000  0.000000  2.000000   11.133300
# 9         1.0  2.000000  14.000000  1.000000  0.000000   30.070800
# 10        1.0  3.000000   4.000000  1.000000  1.000000   16.700000
# 11        1.0  1.000000  58.000000  0.000000  0.000000   26.550000
# 15        1.0  2.000000  55.000000  0.000000  0.000000   16.000000
# 17        1.0  2.000000        NaN  0.000000  0.000000   13.000000
# 19        1.0  3.000000        NaN  0.000000  0.000000    7.225000
# 21        1.0  2.000000  34.000000  0.000000  0.000000   13.000000
# 22        1.0  3.000000  15.000000  0.000000  0.000000    8.029200
# 23        1.0  1.000000  28.000000  0.000000  0.000000   35.500000
# ...

# %%
k1.shape
# Out:
# (549, 8)

# %%
k2.shape
# Out:
# (342, 8)

# %%
r.shape
# Out:
# (207, 8)

# %%
k2.append(r).shape
# Out:
# (549, 8)

# %%
k3=k2.append(r)

# %%
k3.shape
# Out:
# (549, 8)

# %%
k1.shape[0]==k3.shape[0]
# Out:
# True

# %%
r.mean()
# Out:
# survived       1.000000
# pclass         1.972625
# age           28.152338
# sibsp          0.483092
# parch          0.475040
# fare          49.148766
# adult_male     0.264895
# alone          0.476651
# dtype: float64

# %%
r.isna().sum()
# Out:
# survived       0
# pclass         0
# age           73
# sibsp          0
# parch          0
# fare           0
# adult_male     0
# alone          0
# dtype: int64

# %%
for i in r:
    r[i].fillna(r[i].mean(),inplace=True)
r
# Out:
#      survived    pclass        age     sibsp     parch        fare  \
# 0         1.0  2.333333  29.333333  0.333333  0.666667   24.052767
# 1         1.0  1.333333  36.000000  1.000000  0.333333   36.826400
# 2         1.0  2.333333  24.333333  0.666667  0.333333   12.663867
# 3         1.0  2.333333  21.666667  0.333333  0.333333   14.641667
# 4         1.0  1.000000  26.000000  0.000000  0.000000   30.000000
# 5         1.0  2.333333  28.152338  0.333333  0.333333   42.304167
# 6         1.0  2.333333  28.152338  1.333333  1.000000   39.833333
# 7         1.0  2.333333  12.806667  0.333333  1.000000   45.163900
# 8         1.0  1.333333  28.152338  0.333333  0.000000   29.637500
# 9         1.0  1.666667  27.666667  1.333333  2.000000   55.000000
# 10        1.0  2.000000  29.333333  0.333333  0.333333   56.183333
# 11        1.0  2.666667  16.610000  1.333333  1.333333   31.140267
# 12        1.0  1.666667  28.152338  0.333333  0.000000   24.000000
# ...

# %%
r.isna().sum()
# Out:
# survived      0
# pclass        0
# age           0
# sibsp         0
# parch         0
# fare          0
# adult_male    0
# alone         0
# dtype: int64

# %%
k3=k2.append(r)

# %%
k3.isna().sum()
# Out:
# survived       0
# pclass         0
# age           52
# sibsp          0
# parch          0
# fare           0
# adult_male     0
# alone          0
# dtype: int64

# %%
for i in k3:
    k3[i].fillna(k3[i].mean(),inplace=True)
k3
# Out:
#      survived    pclass        age     sibsp     parch        fare  \
# 1         1.0  1.000000  38.000000  1.000000  0.000000   71.283300
# 2         1.0  3.000000  26.000000  0.000000  0.000000    7.925000
# 3         1.0  1.000000  35.000000  1.000000  0.000000   53.100000
# 8         1.0  3.000000  27.000000  0.000000  2.000000   11.133300
# 9         1.0  2.000000  14.000000  1.000000  0.000000   30.070800
# 10        1.0  3.000000   4.000000  1.000000  1.000000   16.700000
# 11        1.0  1.000000  58.000000  0.000000  0.000000   26.550000
# 15        1.0  2.000000  55.000000  0.000000  0.000000   16.000000
# 17        1.0  2.000000  28.263992  0.000000  0.000000   13.000000
# 19        1.0  3.000000  28.263992  0.000000  0.000000    7.225000
# 21        1.0  2.000000  34.000000  0.000000  0.000000   13.000000
# 22        1.0  3.000000  15.000000  0.000000  0.000000    8.029200
# 23        1.0  1.000000  28.000000  0.000000  0.000000   35.500000
# ...

# %%
k3.isna().sum()
# Out:
# survived      0
# pclass        0
# age           0
# sibsp         0
# parch         0
# fare          0
# adult_male    0
# alone         0
# dtype: int64

# %%
char
# Out:
# ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive']

# %%
k1.isna().sum()
# Out:
# survived        0
# pclass          0
# age           125
# sibsp           0
# parch           0
# fare            0
# adult_male      0
# alone           0
# dtype: int64

# %%
for i in k1:
    k1[i].fillna(k1[i].mean(),inplace=True)
# Out:
# C:\Users\156125\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
k1.isna().sum()
# Out:
# survived      0
# pclass        0
# age           0
# sibsp         0
# parch         0
# fare          0
# adult_male    0
# alone         0
# dtype: int64
